# %%
import pandas as pd
import requests
import xml.etree.ElementTree as ET # Biblioteca nativa para ler XML
import json
import time


URL_API = "https://alegre-es.portaltp.com.br/api/transparencia.asmx/json_pagamentos"

dados_acumulados = []

print("--- INÍCIO DA EXTRAÇÃO ---")

# Loop 1: Anos
for ano in range(2015, 2026):
    # Loop 2: Meses (Janeiro a Dezembro)
    for mes in range(1, 13):
        print(f"Baixando {mes:02d}/{ano}...", end="")

        # Parâmetros que a API espera (Query String)
        params = {"ano": ano, "mes": mes}

        try:
            # 1. Bate na porta do servidor (GET)
            response = requests.get(URL_API, params=params, timeout=10)

            if response.status_code == 200:
                # 2. Quebra a casca do XML
                # A API devolve: <string> ...conteudo json... </string>
                # O comando .fromstring converte o texto da resposta em objeto XML
                xml_root = ET.fromstring(response.content)

                # O .text pega o conteúdo de dentro da tag <string>
                conteudo_json = xml_root.text

                # 3. Lê o JSON (se existir conteúdo)
                if conteudo_json:
                    dados = json.loads(conteudo_json) # Converte string JSON para Lista Python

                    if len(dados) > 0:
                        # Transforma lista de dicionários em DataFrame e guarda
                        df_temp = pd.DataFrame(dados)
                        dados_acumulados.append(df_temp)
                        print(f" OK! ({len(dados)} registros)")
                    else:
                        print(" Vazio.")
                else:
                    print(" XML vazio.")
            else:
                print(f" Erro HTTP: {response.status_code}")

        except Exception as e:
            print(f" Falha de conexão: {e}")

        # Pequena pausa para não ser bloqueado pelo servidor (Good Citizen)
        # time.sleep(0.1)

# 4. Consolidação
if dados_acumulados:
    # 'concat' cola todos os pedacinhos (dataframes mensais) em um só
    df_final = pd.concat(dados_acumulados, ignore_index=True)

    # Salvo em CSV
    df_final.to_csv("dados_brutos.csv", index=False, encoding='utf-8-sig')
    print(f"\nSucesso! Arquivo 'dados_brutos.csv' salvo com {len(df_final)} linhas.")
else:
    print("Nenhum dado foi baixado.")
# Out:
# --- INÍCIO DA EXTRAÇÃO ---
# Baixando 01/2015... OK! (777 registros)
# Baixando 02/2015... OK! (623 registros)
# Baixando 03/2015... OK! (788 registros)
# Baixando 04/2015... OK! (749 registros)
# Baixando 05/2015... OK! (772 registros)
# Baixando 06/2015... OK! (894 registros)
# Baixando 07/2015... OK! (782 registros)
# Baixando 08/2015... OK! (851 registros)
# Baixando 09/2015... OK! (699 registros)
# Baixando 10/2015... OK! (1023 registros)
# Baixando 11/2015... OK! (804 registros)
# Baixando 12/2015... OK! (999 registros)
# Baixando 01/2016... OK! (727 registros)
# Baixando 02/2016... OK! (584 registros)
# Baixando 03/2016... OK! (887 registros)
# Baixando 04/2016... OK! (762 registros)
# Baixando 05/2016... OK! (862 registros)
# Baixando 06/2016... OK! (969 registros)
# Baixando 07/2016... OK! (848 registros)
# Baixando 08/2016... OK! (861 registros)
# Baixando 09/2016... OK! (751 registros)
# Baixando 10/2016... OK! (882 registros)
# Baixando 11/2016... OK! (844 registros)
# Baixando 12/2016... OK! (1201 registros)
# Baixando 01/2017... OK! (384 registros)
# Baixando 02/2017... OK! (532 registros)
# Baixando 03/2017... OK! (798 registros)
# Baixando 04/2017... OK! (610 registros)
# Baixando 05/2017... OK! (825 registros)
# Baixando 06/2017... OK! (828 registros)
# Baixando 07/2017... OK! (719 registros)
# Baixando 08/2017... OK! (841 registros)
# Baixando 09/2017... OK! (831 registros)
# Baixando 10/2017... OK! (808 registros)
# Baixando 11/2017... OK! (892 registros)
# Baixando 12/2017... OK! (1247 registros)
# Baixando 01/2018... OK! (583 registros)
# Baixando 02/2018... OK! (732 registros)
# Baixando 03/2018... OK! (882 registros)
# Baixando 04/2018... OK! (895 registros)
# Baixando 05/2018... OK! (1045 registros)
# Baixando 06/2018... OK! (861 registros)
# Baixando 07/2018... OK! (1048 registros)
# Baixando 08/2018... OK! (1023 registros)
# Baixando 09/2018... OK! (799 registros)
# Baixando 10/2018... OK! (916 registros)
# Baixando 11/2018... OK! (1010 registros)
# Baixando 12/2018... OK! (1382 registros)
# Baixando 01/2019... OK! (727 registros)
# Baixando 02/2019... OK! (736 registros)
# Baixando 03/2019... OK! (538 registros)
# Baixando 04/2019... OK! (800 registros)
# Baixando 05/2019... OK! (928 registros)
# Baixando 06/2019... OK! (896 registros)
# Baixando 07/2019... OK! (921 registros)
# Baixando 08/2019... OK! (889 registros)
# Baixando 09/2019... OK! (829 registros)
# Baixando 10/2019... OK! (855 registros)
# Baixando 11/2019... OK! (903 registros)
# Baixando 12/2019... OK! (1258 registros)
# Baixando 01/2020... OK! (666 registros)
# Baixando 02/2020... OK! (630 registros)
# Baixando 03/2020... OK! (905 registros)
# Baixando 04/2020... OK! (703 registros)
# Baixando 05/2020... OK! (775 registros)
# Baixando 06/2020... OK! (756 registros)
# Baixando 07/2020... OK! (901 registros)
# Baixando 08/2020... OK! (902 registros)
# Baixando 09/2020... OK! (686 registros)
# Baixando 10/2020... OK! (913 registros)
# Baixando 11/2020... OK! (953 registros)
# Baixando 12/2020... OK! (1386 registros)
# Baixando 01/2021... OK! (438 registros)
# Baixando 02/2021... OK! (691 registros)
# Baixando 03/2021... OK! (840 registros)
# Baixando 04/2021... OK! (817 registros)
# Baixando 05/2021... OK! (768 registros)
# Baixando 06/2021... OK! (850 registros)
# Baixando 07/2021... OK! (872 registros)
# Baixando 08/2021... OK! (817 registros)
# Baixando 09/2021... OK! (952 registros)
# Baixando 10/2021... OK! (864 registros)
# Baixando 11/2021... OK! (992 registros)
# Baixando 12/2021... OK! (1340 registros)
# Baixando 01/2022... OK! (259 registros)
# Baixando 02/2022... OK! (839 registros)
# Baixando 03/2022... OK! (883 registros)
# Baixando 04/2022... OK! (802 registros)
# Baixando 05/2022... OK! (784 registros)
# Baixando 06/2022... OK! (508 registros)
# Baixando 07/2022... OK! (958 registros)
# Baixando 08/2022... OK! (1022 registros)
# Baixando 09/2022... OK! (1199 registros)
# Baixando 10/2022... OK! (1072 registros)
# Baixando 11/2022... OK! (1000 registros)
# Baixando 12/2022... OK! (1954 registros)
# Baixando 01/2023... OK! (310 registros)
# Baixando 02/2023... OK! (861 registros)
# Baixando 03/2023... OK! (935 registros)
# Baixando 04/2023... OK! (947 registros)
# Baixando 05/2023... OK! (958 registros)
# Baixando 06/2023... OK! (1024 registros)
# Baixando 07/2023... OK! (1082 registros)
# Baixando 08/2023... OK! (1301 registros)
# Baixando 09/2023... OK! (1065 registros)
# Baixando 10/2023... OK! (1014 registros)
# Baixando 11/2023... OK! (1276 registros)
# Baixando 12/2023... OK! (1702 registros)
# Baixando 01/2024... OK! (511 registros)
# Baixando 02/2024... OK! (851 registros)
# Baixando 03/2024... OK! (921 registros)
# Baixando 04/2024... OK! (1014 registros)
# Baixando 05/2024... OK! (1003 registros)
# Baixando 06/2024... OK! (1058 registros)
# Baixando 07/2024... OK! (1153 registros)
# Baixando 08/2024... OK! (1092 registros)
# Baixando 09/2024... OK! (1027 registros)
# Baixando 10/2024... OK! (1070 registros)
# Baixando 11/2024... OK! (854 registros)
# Baixando 12/2024... OK! (1607 registros)
# Baixando 01/2025... OK! (422 registros)
# Baixando 02/2025... OK! (777 registros)
# Baixando 03/2025... OK! (851 registros)
# Baixando 04/2025... OK! (886 registros)
# Baixando 05/2025... OK! (904 registros)
# Baixando 06/2025... OK! (966 registros)
# Baixando 07/2025... OK! (1017 registros)
# Baixando 08/2025... OK! (903 registros)
# Baixando 09/2025... OK! (1017 registros)
# Baixando 10/2025... OK! (898 registros)
# Baixando 11/2025... OK! (755 registros)
# Baixando 12/2025... OK! (1731 registros)
#
# Sucesso! Arquivo 'dados_brutos.csv' salvo com 118170 linhas.

# %%
df = pd.read_csv('/content/dados_brutos.csv')

# %%
import pandas as pd
import requests
URL_SIDRA = 'https://apisidra.ibge.gov.br/values/t/6579/n6/3200201/v/all/p/all'

print(f'------ INICIANDO EXTRAÇÃO DOS DADOS ------: {URL_SIDRA}')

try:
  response = requests.get(URL_SIDRA, timeout=15)

  if response.status_code == 200:
    data = response.json()

    df_ibge_raw = pd.DataFrame(data)
  else:
    print(f"Erro na api: {response.status_code}")
except Exception as e:
  print(f"Falha na conexão: {e}")
  exit()
# Out:
# ------ INICIANDO EXTRAÇÃO DOS DADOS ------: https://apisidra.ibge.gov.br/values/t/6579/n6/3200201/v/all/p/all

# %%
df_ibge_raw.head()
# Out:
#                            NC                 NN                          MC  \
# 0  Nível Territorial (Código)  Nível Territorial  Unidade de Medida (Código)
# 1                           6          Município                          45
# 2                           6          Município                          45
# 3                           6          Município                          45
# 4                           6          Município                          45
#
#                   MN      V                 D1C          D1N  \
# 0  Unidade de Medida  Valor  Município (Código)    Município
# 1            Pessoas  31878             3200201  Alegre (ES)
# 2            Pessoas  31986             3200201  Alegre (ES)
# 3            Pessoas  32112             3200201  Alegre (ES)
# 4            Pessoas  32377             3200201  Alegre (ES)
#
#                  D2C                           D2N           D3C   D3N
# 0  Variável (Código)                      Variável  Ano (Código)   Ano
# 1               9324  População residente estimada          2001  2001
# 2               9324  População residente estimada          2002  2002
# 3               9324  População residente estimada          2003  2003
# 4               9324  População residente estimada          2004  2004

# %%
dados_brutos_ibge = "dados_brutos_ibge.csv"
df_ibge_raw.to_csv(dados_brutos_ibge, index=False)

# %%
df_ibge = df_ibge_raw[['V','D3N']]

# %%
df_ibge.head()
# Out:
#        V   D3N
# 0  Valor   Ano
# 1  31878  2001
# 2  31986  2002
# 3  32112  2003
# 4  32377  2004

# %%
df_ibge = df_ibge.rename(columns={'V': 'populacao_ano', 'D3N': 'ano'})

# %%
df_ibge = df_ibge[df_ibge['ano'].str.isnumeric()]

# %%
df_ibge['ano'] = df_ibge['ano'].astype(int)
df_ibge['populacao_ano'] = pd.to_numeric(df_ibge['populacao_ano'], errors='coerce')

# %%
df_ibge.head()
# Out:
#    populacao_ano   ano
# 1          31878  2001
# 2          31986  2002
# 3          32112  2003
# 4          32377  2004
# 5          32523  2005

# %%
df_ibge_final = df_ibge[(df_ibge['ano'] >= 2015) & (df_ibge['ano'] <= 2025)]

# %%
df_ibge_final
# Out:
#     populacao_ano   ano
# 13          32205  2015
# 14          32175  2016
# 15          32146  2017
# 16          30568  2018
# 17          30084  2019
# 18          29975  2020
# 19          29869  2021
# 20          30744  2024
# 21          30702  2025

# %%
dados_final_ibge = "dados_final_ibge.csv"
df_ibge_final.to_csv(dados_final_ibge, index=False)

# %%
df.head()
# Out:
#     ano           mes                 unidade_gestora                 data  \
# 0  2015  01 - Janeiro     Fundo de Educacao de Alegre  2015-01-13T00:00:00
# 1  2015  01 - Janeiro  Prefeitura Municipal de Alegre  2015-01-28T00:00:00
# 2  2015  01 - Janeiro  Prefeitura Municipal de Alegre  2015-01-28T00:00:00
# 3  2015  01 - Janeiro  Prefeitura Municipal de Alegre  2015-01-28T00:00:00
# 4  2015  01 - Janeiro  Prefeitura Municipal de Alegre  2015-01-28T00:00:00
#
#     especie empenho liquidacao     pagamento      tipo_pagamento  \
# 0  Original     NaN        NaN  0000023/2015  Extra Orcamentario
# 1  Original     NaN        NaN  0000178/2015  Extra Orcamentario
# 2  Original     NaN        NaN  0000179/2015  Extra Orcamentario
# 3  Original     NaN        NaN  0000198/2015  Extra Orcamentario
# 4  Original     NaN        NaN  0000199/2015  Extra Orcamentario
#
#                                   elemento_despesa subtitulo funcao subfuncao  \
# 0  218810102001 - INSS SERVICOS DE TERCEIROS PF/PJ       NaN    NaN       NaN
# 1                     113810600005 - FGTS EDUCACAO       NaN    NaN       NaN
# 2                  113810600006 - FGTS ACAO SOCIAL       NaN    NaN       NaN
# 3               113810600011 - RPPS SOCIAL EMPRESA       NaN    NaN       NaN
# 4  113810600012 - RPPS SOCIAL ALIQUOTA SUPLEMENTAR       NaN    NaN       NaN
#
#   programa                                      fonte_recurso grupo_despesa  \
# 0      NaN  1103000000 - FUNDEB - PAGAMENTO DOS PROFISSION...           NaN
# 1      NaN                   1000000000 - RECURSOS ORDINARIOS           NaN
# 2      NaN                   1000000000 - RECURSOS ORDINARIOS           NaN
# 3      NaN                   1000000000 - RECURSOS ORDINARIOS           NaN
# 4      NaN                   1000000000 - RECURSOS ORDINARIOS           NaN
#
#   documento_favorecido                                    nome_favorecido  \
# 0   29.979.036/0001-40         INSTITUTO NACIONAL DO SEGURO SOCIAL - INSS
# 1   00.360.305/0001-04                            CAIXA ECONOMICA FEDERAL
# 2   00.360.305/0001-04                            CAIXA ECONOMICA FEDERAL
# 3   05.269.863/0001-82  INSTITUTO DE PREVIDENCIA E ASSISTENCIA DO MUNI...
# 4   05.269.863/0001-82  INSTITUTO DE PREVIDENCIA E ASSISTENCIA DO MUNI...
#
#      valor
# 0   132.00
# 1   152.02
# 2  2669.82
# 3  2912.42
# 4  3904.64

# %%
df.describe()
# Out:
#                  ano         valor
# count  118170.000000  1.181700e+05
# mean     2020.206575  8.998155e+03
# std         3.161403  3.360458e+04
# min      2015.000000 -7.250000e+05
# 25%      2018.000000  2.579300e+02
# 50%      2020.000000  1.266500e+03
# 75%      2023.000000  5.063488e+03
# max      2025.000000  2.974786e+06

# %%
df.columns
# Out:
# Index(['ano', 'mes', 'unidade_gestora', 'data', 'especie', 'empenho',
#        'liquidacao', 'pagamento', 'tipo_pagamento', 'elemento_despesa',
#        'subtitulo', 'funcao', 'subfuncao', 'programa', 'fonte_recurso',
#        'grupo_despesa', 'documento_favorecido', 'nome_favorecido', 'valor'],
#       dtype='object')

# %%
df['funcao']
# Out:
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#                  ...
# 118165            10 - SAUDE
# 118166        15 - URBANISMO
# 118167            10 - SAUDE
# 118168        15 - URBANISMO
# 118169    04 - ADMINISTRACAO
# Name: funcao, Length: 118170, dtype: object

# %%
df1 = df[['funcao', 'unidade_gestora']]

# %%
df1.head()
# Out:
#   funcao                 unidade_gestora
# 0    NaN     Fundo de Educacao de Alegre
# 1    NaN  Prefeitura Municipal de Alegre
# 2    NaN  Prefeitura Municipal de Alegre
# 3    NaN  Prefeitura Municipal de Alegre
# 4    NaN  Prefeitura Municipal de Alegre

# %%
df['unidade_gestora'].isna().sum()
# Out:
# np.int64(0)

# %%
print(len(df))
# Out:
# 118170

# %%
print(df['unidade_gestora'].value_counts())
# Out:
# unidade_gestora
# Prefeitura Municipal de Alegre                               39507
# Fundo de Saude de Alegre                                     35650
# Fundo de Educacao de Alegre                                  22487
# Fundo de Assistencia Social de Alegre                        15655
# SAAE SERVICO AUTONOMO DE AGUA E ESGOTO                        4171
# FAFIA  FACULDADE DE FILOSOFIA CIENCIAS E LETRAS DE ALEGRE      700
# Name: count, dtype: int64

# %%
qtd_nulos = df1.isna().sum()
print(qtd_nulos)
# Out:
# 22646

# %%
# Mostra quantas vezes cada categoria aparece + os NaN
print(df1.value_counts(dropna=False))
# Out:
# funcao
# 10 - SAUDE                   29482
# NaN                          22646
# 04 - ADMINISTRACAO           19604
# 12 - EDUCACAO                15703
# 08 - ASSISTENCIA SOCIAL      11407
# 15 - URBANISMO                5614
# 20 - AGRICULTURA              3241
# 28 - ENCARGOS ESPECIAIS       3156
# 18 - GESTAO AMBIENTAL         2374
# 17 - SANEAMENTO               1531
# 13 - CULTURA                  1323
# 02 - JUDICIARIA                828
# 25 - ENERGIA                   567
# 27 - DESPORTO E LAZER          350
# 06 - SEGURANCA PUBLICA         195
# 23 - COMERCIO E SERVICOS       145
# 16 - HABITACAO                   2
# 19 - CIENCIA E TECNOLOGIA        2
# Name: count, dtype: int64

# %%
total = len(df1)
nulos = df1.isna().sum()
porc = (nulos/total) * 100
print(porc)
# Out:
# 19.163916391639162
